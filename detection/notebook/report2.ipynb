# %%
# %matplotlib inline
import os
import sys
cwd = os.getcwd()
sys.path.append(os.path.join(cwd, '..'))

import cv2
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from aye.train import Trainer

# %%
k = 0.4
n_green = 7
n_red = 7
s = 0.4

# %% [markdown]
# # Improved detection with both red and green

# %%
red1 = Trainer('red', k=k, n_images=n, test_size=s, use_ind=False)
red1.train()
# Out:
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/red/frame0000.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/red/frame0001.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/red/frame0002.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/red/frame0003.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/red/frame0004.png
# Finish loading training data
# X: (33995, 9), y:(33995,)
# Pos: 15441, Neg: 18554
# Scale all data using StandardScaler
# Train: 20397, Valid: 13598
# Tuning classifiers
# All Parameters Searched:
# 0.991 (+/-0.002) for {'kernel': 'rbf', 'C': 0.01}
# 0.992 (+/-0.003) for {'kernel': 'rbf', 'C': 0.05}
# 0.992 (+/-0.003) for {'kernel': 'rbf', 'C': 0.1}
# 0.993 (+/-0.004) for {'kernel': 'rbf', 'C': 0.5}
# 0.994 (+/-0.005) for {'kernel': 'rbf', 'C': 1}
# 0.994 (+/-0.004) for {'kernel': 'rbf', 'C': 5}
# 0.994 (+/-0.004) for {'kernel': 'rbf', 'C': 10}
# 0.994 (+/-0.004) for {'kernel': 'rbf', 'C': 50}
# 0.994 (+/-0.004) for {'kernel': 'rbf', 'C': 100}
#
# Optimal Parameters:
# {'kernel': 'rbf', 'C': 5}
# Best Score:
# 0.994019021473
# Test score: 0.994337402559

# %%
red1.validate()
# Out:
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/red/frame0005.png

# %%
red2 = Trainer('red', k=k, n_images=n, test_size=s, use_ind=True)
red2.train()
# Out:
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/red/frame0000.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/red/frame0001.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/red/frame0002.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/red/frame0003.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/red/frame0004.png
# Finish loading training data
# X: (33995, 11), y:(33995,)
# Pos: 15441, Neg: 18554
# Scale all data using StandardScaler
# Train: 20397, Valid: 13598
# Tuning classifiers
# All Parameters Searched:
# 0.994 (+/-0.002) for {'kernel': 'rbf', 'C': 0.01}
# 0.996 (+/-0.001) for {'kernel': 'rbf', 'C': 0.05}
# 0.996 (+/-0.001) for {'kernel': 'rbf', 'C': 0.1}
# 0.997 (+/-0.001) for {'kernel': 'rbf', 'C': 0.5}
# 0.997 (+/-0.000) for {'kernel': 'rbf', 'C': 1}
# 0.997 (+/-0.002) for {'kernel': 'rbf', 'C': 5}
# 0.998 (+/-0.001) for {'kernel': 'rbf', 'C': 10}
# 0.997 (+/-0.001) for {'kernel': 'rbf', 'C': 50}
# 0.997 (+/-0.002) for {'kernel': 'rbf', 'C': 100}
#
# Optimal Parameters:
# {'kernel': 'rbf', 'C': 10}
# Best Score:
# 0.997548779292
# Test score: 0.996396528901

# %%
red2.validate()
# Out:
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/red/frame0005.png

# %%
green1 = Trainer('green', k=k, n_images=n_green, test_size=s, use_ind=False)
green1.train()
# Out:
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0000.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0001.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0002.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0003.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0004.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0005.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0006.png
# Finish loading training data
# X: (21938, 9), y:(21938,)
# Pos: 10369, Neg: 11569
# Scale all data using StandardScaler
# Train: 13162, Valid: 8776
# Tuning classifiers
# All Parameters Searched:
# 0.914 (+/-0.015) for {'kernel': 'rbf', 'C': 0.01}
# 0.919 (+/-0.013) for {'kernel': 'rbf', 'C': 0.05}
# 0.920 (+/-0.014) for {'kernel': 'rbf', 'C': 0.1}
# 0.922 (+/-0.015) for {'kernel': 'rbf', 'C': 0.5}
# 0.922 (+/-0.014) for {'kernel': 'rbf', 'C': 1}
# 0.922 (+/-0.015) for {'kernel': 'rbf', 'C': 5}
# 0.922 (+/-0.017) for {'kernel': 'rbf', 'C': 10}
# 0.921 (+/-0.019) for {'kernel': 'rbf', 'C': 50}
# 0.921 (+/-0.015) for {'kernel': 'rbf', 'C': 100}
#
# Optimal Parameters:
# {'kernel': 'rbf', 'C': 0.5}
# Best Score:
# 0.921744415742
# Test score: 0.916020966272

# %%
green1.validate()
# Out:
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0007.png

# %%
green2 = Trainer('green', k=k, n_images=n_green, test_size=s, use_ind=True)
green2.train()
# Out:
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0000.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0001.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0002.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0003.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0004.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0005.png
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0006.png
# Finish loading training data
# X: (21938, 11), y:(21938,)
# Pos: 10369, Neg: 11569
# Scale all data using StandardScaler
# Train: 13162, Valid: 8776
# Tuning classifiers
# All Parameters Searched:
# 0.920 (+/-0.015) for {'kernel': 'rbf', 'C': 0.01}
# 0.939 (+/-0.008) for {'kernel': 'rbf', 'C': 0.05}
# 0.945 (+/-0.006) for {'kernel': 'rbf', 'C': 0.1}
# 0.956 (+/-0.004) for {'kernel': 'rbf', 'C': 0.5}
# 0.957 (+/-0.004) for {'kernel': 'rbf', 'C': 1}
# 0.960 (+/-0.005) for {'kernel': 'rbf', 'C': 5}
# 0.961 (+/-0.006) for {'kernel': 'rbf', 'C': 10}
# 0.961 (+/-0.005) for {'kernel': 'rbf', 'C': 50}
# 0.961 (+/-0.006) for {'kernel': 'rbf', 'C': 100}
#
# Optimal Parameters:
# {'kernel': 'rbf', 'C': 50}
# Best Score:
# 0.961404041939
# Test score: 0.966271649954

# %%
green2.validate()
# Out:
# /home/chao/Workspace/repo/kumar_robotics/Galt/detection/notebook/../data/green/frame0007.png
